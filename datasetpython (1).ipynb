# %%
import pandas as pd
import numpy as np

# %%
singapore = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\dataset\covid19.csv')
world = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\dataset\owid-covid-data.csv')
sg = pd.DataFrame(singapore)
sg
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 singapore = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\dataset\covid19.csv')
#       2 world = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\dataset\owid-covid-data.csv')
#       3 sg = pd.DataFrame(singapore)
#
# File c:\Users\motor\OneDrive\Desktop\SIT Y1S1\INF1002 Programming fundamentals\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
singapore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 36 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Date                                                           717 non-null    object
#  1   Daily Confirmed                                                717 non-null    int64
#  2   False Positives Found                                          608 non-null    float64
#  3   Cumulative Confirmed                                           717 non-null    int64
#  4   Daily Discharged                                               717 non-null    int64
#  5   Passed but not due to COVID                                    717 non-null    int64
#  6   Cumulative Discharged                                          717 non-null    int64
# ...

# %%
sg.iloc[[1,2]]
# Out:
#          Date  Daily Confirmed  False Positives Found  Cumulative Confirmed  \
# 1  2020-01-24                2                    NaN                     3
# 2  2020-01-25                1                    NaN                     4
#
#    Daily Discharged  Passed but not due to COVID  Cumulative Discharged  \
# 1                 0                            0                      0
# 2                 0                            0                      0
#
#    Discharged to Isolation  Still Hospitalised  Daily Deaths  ...  \
# 1                        0                   3             0  ...
# 2                        0                   4             0  ...
#
#    Cumulative Individuals Vaccinated  \
# 1                                NaN
# 2                                NaN
#
#    Cumulative Individuals Vaccination Completed  \
# 1                                           NaN
# 2                                           NaN
#
# ...

# %%
sg.loc[1:2, 'Cumulative Confirmed':'Daily Deaths']
# Out:
#    Cumulative Confirmed  Daily Discharged  Passed but not due to COVID  \
# 1                     3                 0                            0
# 2                     4                 0                            0
#
#    Cumulative Discharged  Discharged to Isolation  Still Hospitalised  \
# 1                      0                        0                   3
# 2                      0                        0                   4
#
#    Daily Deaths
# 1             0
# 2             0

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216106 entries, 0 to 216105
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    216106 non-null  object
#  1   continent                                   203645 non-null  object
#  2   location                                    216106 non-null  object
#  3   date                                        216106 non-null  object
#  4   total_cases                                 206944 non-null  float64
#  5   new_cases                                   206671 non-null  float64
#  6   new_cases_smoothed                          205489 non-null  float64
#  7   total_deaths                                188114 non-null  float64
#  8   new_deaths                                  188042 non-null  float64
# ...

# %%
d = world['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 216101       Zimbabwe
# 216102       Zimbabwe
# 216103       Zimbabwe
# 216104       Zimbabwe
# 216105       Zimbabwe
# Name: location, Length: 216106, dtype: object

# %%
world.nlargest(10,'location')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 world.nlargest(10,'location')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6690, in DataFrame.nlargest(self, n, columns, keep)
#    6585 def nlargest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#    6586     """
#    6587     Return the first `n` rows ordered by `columns` in descending order.
#    6588
#    (...)
#    6688     Brunei      434000    12128      BN
#    6689     """
# -> 6690     return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:1137, in SelectN.nlargest(self)
#    1135 @final
#    1136 def nlargest(self):
# -> 1137     return self.compute("nlargest")
#
# ...
