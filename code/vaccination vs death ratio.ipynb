# %%
import pandas as pd
import numpy as np

# %%
world = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\INF1002 Programming fundamentals\python first project\New folder\INF1002-assignment-1\csv\covid-vaccination-vs-death_ratio.csv')
pd.set_option('display.max_columns', 50000)

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32911 entries, 0 to 32910
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    32911 non-null  int64
#  1   country                       32911 non-null  object
#  2   iso_code                      32911 non-null  object
#  3   date                          32911 non-null  object
#  4   total_vaccinations            32911 non-null  int64
#  5   people_vaccinated             32911 non-null  int64
#  6   people_fully_vaccinated       32911 non-null  int64
#  7   New_deaths                    32911 non-null  int64
#  8   population                    32911 non-null  int64
#  9   ratio                         32911 non-null  float64
#  10  Percantage of vaccinated ppl  32911 non-null  float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ MB

# %%
count = world.groupby(['country'])

# %%
a = count.max()
pd.set_option('display.max_rows', 20000)

# %%
b = a['ratio']

# %%
b.sort_values()
# Out:
# country
# Burundi                                                       0.083178
# Haiti                                                         1.408404
# Chad                                                          1.639191
# Yemen                                                         2.083710
# Papua New Guinea                                              3.439691
# Madagascar                                                    3.806883
# South Sudan                                                   4.578634
# Cameroon                                                      4.882577
# Mali                                                          6.278956
# United Republic of Tanzania                                   6.302860
# Malawi                                                        7.869988
# Senegal                                                       8.344168
# Niger                                                         8.493604
# ...

# %%
#this result shows a good statistics on vaccination vs death ratio in ascending order for the latest date.

# %%
x = world.groupby(['country'])

# %%
maximums = x.max()
maximums = maximums.reset_index()
sorting=maximums[['country','Percantage of vaccinated ppl']]

# %%
sorted=sorting.sort_values(by=['Percantage of vaccinated ppl'], ascending=[False])
sorted #calculated the percentage of vaccinated ppl in a country
# Out:
#                                                country  \
# 68                                           Gibraltar
# 109                                              Malta
# 184                               United Arab Emirates
# 140                                           Portugal
# 27                                   Brunei Darussalam
# 38                                               Chile
# 35                                      Cayman Islands
# 45                                                Cuba
# 129                                               Niue
# 142                                  Republic of Korea
# 164                                              Spain
# 39                                               China
# 79                                             Iceland
# 157                                          Singapore
# 125                                        New Zealand
# 42                                        Cook Islands
# ...

# %%
#we can establish a trend from the early dates to latest date to see when more ppl get vaccinated, did the ratio improve?
