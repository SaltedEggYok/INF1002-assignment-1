# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\motor\OneDrive\Desktop\SIT Y1S1\INF1002 Programming fundamentals\python first project\New folder\INF1002-assignment-1\csv\Percentage.csv', dtype={'percentage_vaccinated_in_a_country': 'str'})
pd.set_option('display.max_rows', 50000)

# %%
x = data.groupby(['location'])
maximums = x.max()
maximums = maximums.reset_index()
sorting=maximums[['location','percentage_vaccinated_in_a_country']]
percentage=sorting.sort_values(by=['percentage_vaccinated_in_a_country'], ascending=[False])

# %%
percentage  #calculated the percentage of vaccinated ppl in a country
# Out:
#                              location percentage_vaccinated_in_a_country
# 227              United Arab Emirates                        99.90396304
# 31                             Brunei                        99.75750663
# 81                          Gibraltar                        98.84603612
# 177                             Qatar                         98.4500239
# 51                               Cuba                        95.06706068
# 175                          Portugal                        94.76656356
# 42                              Chile                        92.67298252
# 194                         Singapore                        92.12967581
# 237                           Vietnam                        91.94656631
# 35                           Cambodia                         91.4610764
# 43                              China                        91.36538128
# 94                          Hong Kong                         91.2325684
# ...
