# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read retrenchment industry data
df = pd.read_csv("retrench_industry_yearly.csv")
print("Retrenchment industry data read successfully!")
# Out:
# Retrenchment industry data read successfully!

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      year      industry1                                industry2  \
# 0    1998  manufacturing              food, beverages and tobacco
# 1    1998  manufacturing              textile and wearing apparel
# 2    1998  manufacturing            paper products and publishing
# 3    1998  manufacturing          petroleum and chemical products
# 4    1998  manufacturing              rubber and plastic products
# ..    ...            ...                                      ...
# 757  2021       services  community, social and personal services
# 758  2021       services  community, social and personal services
# 759  2021       services  community, social and personal services
# 760  2021       services  community, social and personal services
# 761  2021         others                                   others
#
#                                          industry3 retrench
# 0                      food, beverages and tobacco      230
# 1                      textile and wearing apparel      310
# 2                    paper products and publishing      510
# 3                  petroleum and chemical products      500
# 4                      rubber and plastic products     1100
# ..                                             ...      ...
# 757            public administration and education       60
# 758                     health and social services       10
# 759             arts, entertainment and recreation       70
# 760  other community, social and personal services       40
# 761                                         others       50
#
# [762 rows x 5 columns]>

# %%
# Prints the count, unique, top, freq
# Describe function only takes in float or integer values
df['retrench'].describe()
# Out:
# count     762
# unique    168
# top        10
# freq       36
# Name: retrench, dtype: object

# %%
# To print out a summary of the number of values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762 entries, 0 to 761
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       762 non-null    int64
#  1   industry1  762 non-null    object
#  2   industry2  762 non-null    object
#  3   industry3  762 non-null    object
#  4   retrench   762 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 29.9+ KB

# %%
# Read retrenchment industry data with null values, containing '-'
df = pd.read_csv("retrench_industry_yearly.csv", na_values = ["-"])
df
# Out:
#      year      industry1                                industry2  \
# 0    1998  manufacturing              food, beverages and tobacco
# 1    1998  manufacturing              textile and wearing apparel
# 2    1998  manufacturing            paper products and publishing
# 3    1998  manufacturing          petroleum and chemical products
# 4    1998  manufacturing              rubber and plastic products
# ..    ...            ...                                      ...
# 757  2021       services  community, social and personal services
# 758  2021       services  community, social and personal services
# 759  2021       services  community, social and personal services
# 760  2021       services  community, social and personal services
# 761  2021         others                                   others
#
#                                          industry3  retrench
# 0                      food, beverages and tobacco     230.0
# 1                      textile and wearing apparel     310.0
# 2                    paper products and publishing     510.0
# 3                  petroleum and chemical products     500.0
# 4                      rubber and plastic products    1100.0
# ..                                             ...       ...
# 757            public administration and education      60.0
# 758                     health and social services      10.0
# 759             arts, entertainment and recreation      70.0
# 760  other community, social and personal services      40.0
# 761                                         others      50.0
#
# [762 rows x 5 columns]

# %%
# To print out a summary of the number of missing values, containing '-'
sums = df.isnull().sum()
print(sums)
print("Total Missing Values:", sums.sum())
# Out:
# year          0
# industry1     0
# industry2     0
# industry3     0
# retrench     15
# dtype: int64
# Total Missing Values: 15

# %%
# Make a copy of the original dataframe
# Make a duplicate and make changes from the duplicate set to not make changes to the original dataset
# Drop rows with missing values, , containing '-'
df2 = df.copy()
df2=df2.dropna(how='any')

# %%
# To print out a summary of the number of missing values after dropping them
sums = df2.isnull().sum()
print(sums)
print("Total Missing Values:", sums.sum())
# Out:
# year         0
# industry1    0
# industry2    0
# industry3    0
# retrench     0
# dtype: int64
# Total Missing Values: 0

# %%
# To count the number of rows after dropping missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762 entries, 0 to 761
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       762 non-null    int64
#  1   industry1  762 non-null    object
#  2   industry2  762 non-null    object
#  3   industry3  762 non-null    object
#  4   retrench   747 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 29.9+ KB

# %%
# To drop any rows that have 'others' value in the industry columns 
df3 = df2.copy()
df3 = df3[(df3.industry1 != 'others') & (df3.industry2 != 'others') & (df3.industry3 != 'others')]

# %%
# To count the number of rows after dropping 'others' value in the industry columns 
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 726 entries, 0 to 760
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       726 non-null    int64
#  1   industry1  726 non-null    object
#  2   industry2  726 non-null    object
#  3   industry3  726 non-null    object
#  4   retrench   726 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 34.0+ KB

# %%
# Print out recent 5 years from 2017 to 2021
df4 = df3.loc[(df3['year'] >= 2017) & (df3['year'] <= 2021)]
print(df4)
# Out:
#      year      industry1                                          industry2  \
# 602  2017  manufacturing                        food, beverages and tobacco
# 603  2017  manufacturing         paper,rubber,plastic products and printing
# 604  2017  manufacturing    petroleum, chemical and pharmaceutical products
# 605  2017  manufacturing  fabricated metal products, machinery and equip...
# 606  2017  manufacturing          electronic, computer and optical products
# ..    ...            ...                                                ...
# 756  2021       services                administrative and support services
# 757  2021       services            community, social and personal services
# 758  2021       services            community, social and personal services
# 759  2021       services            community, social and personal services
# 760  2021       services            community, social and personal services
#
#                                              industry3  retrench
# 602                        food, beverages and tobacco     190.0
# 603         paper,rubber,plastic products and printing     480.0
# 604    petroleum, chemical and pharmaceutical products     300.0
# 605  fabricated metal products, machinery and equip...     930.0
# 606          electronic, computer and optical products     920.0
# ..                                                 ...       ...
# 756           other adminstrative and support services     510.0
# 757                public administration and education      60.0
# 758                         health and social services      10.0
# 759                 arts, entertainment and recreation      70.0
# 760      other community, social and personal services      40.0
#
# [155 rows x 5 columns]

# %%
# To export dataframe to csv file after cleaned
df4.to_csv('retrench_industry_yr_cleaned.csv', index=False)

# %%
# Sort retrench value in ascending order
df5 = df4.sort_values(by = ['retrench'])
print(df5)
# Out:
#      year     industry1                                industry2  \
# 658  2018      services      administrative and support services
# 758  2021      services  community, social and personal services
# 754  2021      services      administrative and support services
# 648  2018      services          accommodation and food services
# 690  2019      services      administrative and support services
# ..    ...           ...                                      ...
# 610  2017      services               wholesale and retail trade
# 710  2020      services               transportation and storage
# 609  2017  construction                             construction
# 727  2020      services  community, social and personal services
# 706  2020      services               wholesale and retail trade
#
#                                  industry3  retrench
# 658             security and investigation      10.0
# 758             health and social services      10.0
# 754             security and investigation      10.0
# 648                          accommodation      10.0
# 690             security and investigation      10.0
# ..                                     ...       ...
# 610                        wholesale trade    1920.0
# 710  air transport and supporting services    2000.0
# 609                           construction    2020.0
# 727     arts, entertainment and recreation    2210.0
# 706                        wholesale trade    3810.0
#
# [155 rows x 5 columns]

# %%
df5["industry1"].nunique()
# Out:
# 3

# %%
df5["industry1"].unique()
# Out:
# array(['services', 'manufacturing', 'construction'], dtype=object)

# %%
# Retrieve retrenchment rate by industry type from 2017-2021
df5.groupby(['industry1'])['retrench'].agg('sum')
# Out:
# industry1
# construction      5310.0
# manufacturing    16220.0
# services         48740.0
# Name: retrench, dtype: float64

# %%
# Plot retrenchment rate by industry type from 2017-2021
# Noticed that amongst the 3 unique industry types, services has the most retrenchment rate
plt.rcParams['figure.figsize']=(30,9)
df6 = df5.groupby(['year', 'industry1'])['retrench'].agg('sum').plot.bar(color=['lightsalmon', 'lightblue', 'plum'])
plt.xticks(rotation='horizontal')
plt.show()

# %%
plt.rcParams['figure.figsize']=(20,5)
df7 = df5.boxplot(column='retrench', by='industry1')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df8 = df5.groupby(['industry3'])['retrench'].agg('sum')
df8
# Out:
# industry3
# accommodation                                           900.0
# air transport and supporting services                  2310.0
# architectural and engineering services                 2170.0
# arts, entertainment and recreation                     2670.0
# cleaning and landscaping                                470.0
# construction                                           5310.0
# electronic, computer and optical products              4230.0
# fabricated metal products, machinery and equipment     4050.0
# financial services                                     7310.0
# food and beverage services                             1960.0
# food, beverages and tobacco                             930.0
# health and social services                              220.0
# insurance services                                      550.0
# it and other information services                      2280.0
# land transport and supporting services                  590.0
# legal, accounting and management services              4030.0
# other adminstrative and support services               2690.0
# other community, social and personal services           520.0
# other manufacturing industries                         1470.0
# other professional services                            1120.0
# other transport and storage services                   1870.0
# paper,rubber,plastic products and printing             1110.0
# petroleum, chemical and pharmaceutical products        1340.0
# public administration and education                     510.0
# real estate services                                    600.0
# retail trade                                           2050.0
# security and investigation                              160.0
# telecommunications, broadcasting and publishing        2400.0
# transport equipment                                    3090.0
# water transport and supporting services                 950.0
# wholesale trade                                       10410.0
# Name: retrench, dtype: float64

# %%
# Plot retrenchment rate by industry type from 2017-2021
# Noticed that amongst the 3 unique industry types, services has the most retrenchment rate
plt.rcParams['figure.figsize']=(5,25)
df9 = df5.groupby(['year', 'industry3'])['retrench'].agg('sum').plot.barh(color=['lightsalmon', 'lightblue', 'plum'])
plt.xticks(rotation='horizontal')
plt.show()

# %%
# Option a). Look at the retrenchment rate by industry before Covid-19
df10 = df5.loc[(df5['year'] >= 2017) & (df5['year'] <= 2019)][['year', 'industry3', 'retrench']]
print(df10)
# Out:
#      year                              industry3  retrench
# 658  2018             security and investigation      10.0
# 648  2018                          accommodation      10.0
# 690  2019             security and investigation      10.0
# 662  2018             health and social services      20.0
# 646  2018  air transport and supporting services      20.0
# ..    ...                                    ...       ...
# 642  2018                        wholesale trade    1580.0
# 620  2017                     financial services    1720.0
# 674  2019                        wholesale trade    1850.0
# 610  2017                        wholesale trade    1920.0
# 609  2017                           construction    2020.0
#
# [93 rows x 3 columns]

# %%
# Plot retrenchment rate by industry type before Covid-19
plt.rcParams['figure.figsize']=(5,25)
df11 = df10.groupby(['year', 'industry3'])['retrench'].agg('sum').plot.barh(color=['lightblue'])
plt.xticks(rotation='horizontal')
plt.show()

# %%
# Option b). Look at the retrenchment rate by industry during Covid-19
df12 = df5.loc[df5['year']==2020][['year', 'industry3', 'retrench']]
print(df11)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Plot retrenchment rate by industry type during Covid-19
plt.rcParams['figure.figsize']=(5,25)
df13 = df12.groupby(['year', 'industry3'])['retrench'].agg('sum').plot.barh(color=['lightblue'])
plt.xticks(rotation='horizontal')
plt.show()

# %%
# Option c). Look at the retrenchment rate by industry for the post-recovery Covid-19
df14 = df5.loc[df5['year']==2021][['year', 'industry3', 'retrench']]
print(df14)
# Out:
#      year                                          industry3  retrench
# 758  2021                         health and social services      10.0
# 754  2021                         security and investigation      10.0
# 755  2021                           cleaning and landscaping      20.0
# 760  2021      other community, social and personal services      40.0
# 744  2021                                      accommodation      40.0
# 740  2021             land transport and supporting services      50.0
# 757  2021                public administration and education      60.0
# 749  2021                                 insurance services      70.0
# 759  2021                 arts, entertainment and recreation      70.0
# 736  2021                     other manufacturing industries      70.0
# 731  2021         paper,rubber,plastic products and printing      70.0
# 750  2021                               real estate services     100.0
# 753  2021                        other professional services     100.0
# 730  2021                        food, beverages and tobacco     110.0
# 735  2021                                transport equipment     130.0
# 745  2021                         food and beverage services     130.0
# 743  2021               other transport and storage services     140.0
# 741  2021            water transport and supporting services     140.0
# 733  2021  fabricated metal products, machinery and equip...     150.0
# 752  2021             architectural and engineering services     160.0
# 739  2021                                       retail trade     160.0
# 742  2021              air transport and supporting services     220.0
# 737  2021                                       construction     240.0
# 746  2021    telecommunications, broadcasting and publishing     380.0
# 747  2021                  it and other information services     470.0
# 732  2021    petroleum, chemical and pharmaceutical products     500.0
# 756  2021           other adminstrative and support services     510.0
# 751  2021          legal, accounting and management services     660.0
# 734  2021          electronic, computer and optical products     690.0
# 748  2021                                 financial services    1250.0
# 738  2021                                    wholesale trade    1250.0

# %%
# Plot retrenchment rate by industry type for the post-recovery Covid-19
plt.rcParams['figure.figsize']=(5,25)
df15 = df14.groupby(['year', 'industry3'])['retrench'].agg('sum').plot.barh(color=['lightblue'])
plt.xticks(rotation='horizontal')
plt.show()

# %%
df5["industry3"].nunique()
# Out:
# 31
